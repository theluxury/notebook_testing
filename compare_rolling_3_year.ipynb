# %%
import pandas as pd

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a39802b7-0fd0-448b-a28b-ac045aa0412d">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

# spy_500_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SPY.csv')
spxl_50_ma_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SPXL_50_ma.csv')
# spy_500_df = spy_500_df[spy_500_df.Date>= spxl_50_ma_df.Date[0]]
spxl_200_ma_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SPXL_200_ma.csv')
spxl_100_ma_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SPXL_100_ma.csv')
p = figure(title="Simple line example", y_axis_label='3 year delta', x_axis_type="datetime")
# p.line(np.array(spy_500_df['Date'], dtype=np.datetime64), spy_500_df['3 year delta'], legend_label="SPY 500", line_width=2, color='blue')
p.line(np.array(spxl_50_ma_df['Date'], dtype=np.datetime64), spxl_50_ma_df['3 year delta'], legend_label="SPXL 50 MA.", line_width=2, color='red')
p.line(np.array(spxl_100_ma_df['Date'], dtype=np.datetime64), spxl_100_ma_df['3 year delta'], legend_label="SPXL 100 MA.", line_width=2, color='blue')
p.line(np.array(spxl_200_ma_df['Date'], dtype=np.datetime64), spxl_200_ma_df['3 year delta'], legend_label="SPXL 200 MA.", line_width=2, color='green')
show(p)
# Out:
#   <div id="ce091299-f071-443a-897a-46cca4f4c9c7" data-root-id="p2268" style="display: contents;"></div>

# %%
import numpy as np

SSO_50_ma_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SSO_50_ma.csv')
SSO_200_ma_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SSO_200_ma.csv')
SSO_100_ma_df = pd.read_csv('/Users/zhengkanwang/Documents/programming/notebook_testing/output/SSO_100_ma.csv')
p = figure(title="Simple line example", y_axis_label='3 year delta', x_axis_type="datetime")
# p.line(np.array(spy_500_df['Date'], dtype=np.datetime64), spy_500_df['3 year delta'], legend_label="SPY 500", line_width=2, color='blue')
p.line(np.array(SSO_50_ma_df['Date'], dtype=np.datetime64), SSO_50_ma_df['3 year delta'], legend_label="SSO 50 MA.", line_width=2, color='red')
p.line(np.array(SSO_100_ma_df['Date'], dtype=np.datetime64), SSO_100_ma_df['3 year delta'], legend_label="SSO 100 MA.", line_width=2, color='blue')
p.line(np.array(SSO_200_ma_df['Date'], dtype=np.datetime64), SSO_200_ma_df['3 year delta'], legend_label="SSO 200 MA.", line_width=2, color='green')
show(p)
# Out:
#   <div id="a8363885-7856-48cd-b57d-52692e537f17" data-root-id="p2350" style="display: contents;"></div>

# %%
import numpy as np

from bokeh.layouts import column
from bokeh.models import ColumnDataSource, RangeTool
from bokeh.plotting import figure, show
from bokeh.sampledata.stocks import AAPL

dates = np.array(AAPL['date'], dtype=np.datetime64)
source = ColumnDataSource(data=dict(date=dates, close=AAPL['adj_close']))

p = figure(height=300, width=800, tools="xpan", toolbar_location=None,
           x_axis_type="datetime", x_axis_location="above",
           background_fill_color="#efefef", x_range=(dates[1500], dates[2500]))

p.line('date', 'close', source=source)
p.yaxis.axis_label = 'Price'

select = figure(title="Drag the middle and edges of the selection box to change the range above",
                height=130, width=800, y_range=p.y_range,
                x_axis_type="datetime", y_axis_type=None,
                tools="", toolbar_location=None, background_fill_color="#efefef")

range_tool = RangeTool(x_range=p.x_range)
range_tool.overlay.fill_color = "navy"
range_tool.overlay.fill_alpha = 0.2

select.line('date', 'close', source=source)
select.ygrid.grid_line_color = None
select.add_tools(range_tool)

show(column(p, select))
# Out:
#   <div id="b90c6e0d-ccac-46e4-8fe6-b16ea29d5957" data-root-id="p1918" style="display: contents;"></div>

# %%
dates = np.array(AAPL['date'], dtype=np.datetime64)
print(dates)
# Out:
# ['2000-03-01' '2000-03-02' '2000-03-03' ... '2013-02-27' '2013-02-28'
#  '2013-03-01']

# %%
import bokeh
bokeh.sampledata.download()
# Out:
# Creating /Users/zhengkanwang/.bokeh directory
# Creating /Users/zhengkanwang/.bokeh/data directory
# Using data directory: /Users/zhengkanwang/.bokeh/data
# Fetching 'CGM.csv'
# Downloading: CGM.csv (1589982 bytes)
#  1589982   [100.00%%]
# Fetching 'US_Counties.zip'
# Downloading: US_Counties.zip (3171836 bytes)
#  3171836   [100.00%%]
# Unpacking: US_Counties.csv
# Fetching 'us_cities.json'
# Downloading: us_cities.json (713565 bytes)
#  713565    [100.00%%]
# Fetching 'unemployment09.csv'
# Downloading: unemployment09.csv (253301 bytes)
#  253301    [100.00%%]
# Fetching 'AAPL.csv'
# Downloading: AAPL.csv (166698 bytes)
#  166698    [100.00%%]
# Fetching 'FB.csv'
# Downloading: FB.csv (9706 bytes)
#  9706      [100.00%%]
# Fetching 'GOOG.csv'
# Downloading: GOOG.csv (113894 bytes)
#  113894    [100.00%%]
# Fetching 'IBM.csv'
# Downloading: IBM.csv (165625 bytes)
#  165625    [100.00%%]
# Fetching 'MSFT.csv'
# Downloading: MSFT.csv (161614 bytes)
#  161614    [100.00%%]
# ...
